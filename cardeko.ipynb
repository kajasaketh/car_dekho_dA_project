# %% [markdown]
# There are different questions you need to answer by analysing this data -
#
# 1)From which manufacturing year to which manufacturing year vehicles are present in this data ?
# 2)What is the lowest price to which a vehicle is sold ?
# 3)What is the highest price to which a vehicle is sold ?
# 4)How many records are there in this data ?
# 5)Are there any missing records in this data ?
# 6)How many different vehicles are present in this data ?
# 7)Which is the most sold vehicle in this data ?
# 8)Does the database include any CNG vehicle ? If yes how many of them are there ?
# 9)How many vehicles here are for sell from Individuals directly ?
# 10)Does this database contain auto transmission vehicles ? If yes how many of them are there ?
# 11)How many single person owned vehicles are there in this database ?
# 12)Which is the most and least cost depreciated vehicle in data ?
# 13)Which brands of vehicles are less affected by cost depreciation ?
# 14)Are there any factors which you feel affect the cost depreciation ?
# 15)In general selling price is affected by age of vehicle and distance driven by vehicle , is it observable from data ?
# 16)Can we get idea about newest vehicles i.e. after 2014 manufactured ?
# 17)Can we find out data of only two wheelers from this data ?
# Which is the oldest bike sold here?
# 18)Which is the newest bike sold here?
# 19)Which is the most sold bike here?
# 20)Do you find any deal in two wheelers which exceeded the general expectation ? Can you find reason for it ?
# 21)Can we find out data of only cars from this data ?
# 22)Which is the oldest car sold here?
# 23)Which is the newest car sold here?
# 24)Do you find any deal in cars which exceeded the general expectation ? Can you find reason for it ?

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/car_Dekho_DA.csv")

# %%
df = pd.DataFrame(df)

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
# 1 question
maxyear = df["Year"].max()
minyear = df["Year"].min()
print(f"{minyear} to {maxyear}")
# Out:
# 2003 to 2018

# %% [markdown]
# From 2003 manufacturing year to 2018 manufacturing year vehicles are present in this dataset.

# %%
# 2 question
lowestprice = df["Selling_Price"].min()
print(f"lowestprice: {lowestprice} lakhs")
# Out:
# lowestprice: 0.1 lakhs

# %% [markdown]
# Vehicles are sold at a minimum price of 0.1 lakhs.

# %%
# 3 question
highestprice = df["Selling_Price"].max()
print(f"highestprice:{highestprice} lakhs")
# Out:
# highestprice:35.0 lakhs

# %% [markdown]
# Vehicles are sold at a maximum price of 35.0 lakhs.

# %%
# 4 question
num = df.shape[0]
print(f"The number of records in the dataset is:{num}")
# Out:
# The number of records in the dataset is:301

# %% [markdown]
# Total 301 number of records in the data set.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
# 5 question
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %% [markdown]
# no missing records in the data.

# %%
# 6 question
diff_cars = df["Car_Name"].nunique()
print(f"They are {diff_cars} number of different vehicles in the data")
# Out:
# They are 98 number of different vehicles in the data

# %% [markdown]
# They are 98 number of different vehicles in the data

# %%
# 7 question
car_counts = df['Car_Name'].value_counts()
print(car_counts)
most_sold_car = car_counts.idxmax()
print(f"The most sold car is: {most_sold_car}")
# Out:
# Car_Name
# city                        26
# corolla altis               16
# verna                       14
# fortuner                    11
# brio                        10
#                             ..
# Honda CB Trigger             1
# Yamaha FZ S                  1
# Bajaj Pulsar 135 LS          1
# Activa 4g                    1
# Bajaj Avenger Street 220     1
# Name: count, Length: 98, dtype: int64
# The most sold car is: city

# %% [markdown]
# The most sold car in the data is "city" .

# %%
# 8 question
num = (df["Fuel_Type"] == "CNG").sum()
if num > 0:
    print(f"Yes, there are {num} CNG vehicles in the database.")
else:
    print("No, there are no CNG vehicles in the database.")
# Out:
# Yes, there are 2 CNG vehicles in the database.

# %% [markdown]
# YES in the data there are 2 cng fuel_type cars are avalible.

# %%
# 9 question
num = (df["Seller_Type"] == "Individual").sum()
print(f"there are {num} Individual seller_type  vehicles in the database.")
# Out:
# there are 106 Individual seller_type  vehicles in the database.

# %% [markdown]
# there are 106 Individual seller_type  vehicles in the database

# %%
# 10 question
num = (df["Transmission"] == "Automatic").sum()
if num > 0:
    print(f"Yes, there are {num} Automatic vehicles in the database.")
else:
    print("there are no Automatic_Transmission vehicles in the database.")
# Out:
# Yes, there are 40 Automatic vehicles in the database.

# %% [markdown]
# there are 40 Automatic_Transmission vehicles in the database.

# %%
df["Owner"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 296    0
# 297    0
# 298    0
# 299    0
# 300    0
# Name: Owner, Length: 301, dtype: int64

# %%
# 11 question
num = (df["Owner"] == 1).sum()
print(f"there are {num} 1st Owner vehicles in the database.")
# Out:
# there are 10 1st Owner vehicles in the database.

# %% [markdown]
# there are 10 1st Owner vehicles in the database.

# %%
# 12 question
df['Depreciation'] = df['Present_Price'] - df['Selling_Price']
most_depreciated_vehicle = df.loc[df['Depreciation'].idxmax()]
least_depreciated_vehicle = df.loc[df['Depreciation'].idxmin()]

print("Most Depreciated Vehicle:")
print(most_depreciated_vehicle)

print("\nLeast Depreciated Vehicle:")
print(least_depreciated_vehicle)
# Out:
# Most Depreciated Vehicle:
# Car_Name         land cruiser
# Year                     2010
# Selling_Price            35.0
# Present_Price            92.6
# Kms_Driven              78000
# Fuel_Type              Diesel
# Seller_Type            Dealer
# Transmission           Manual
# Owner                       0
# Depreciation             57.6
# Name: 86, dtype: object
#
# Least Depreciated Vehicle:
# Car_Name         Honda Activa 4G
# Year                        2017
# Selling_Price               0.48
# Present_Price               0.51
# Kms_Driven                  4300
# Fuel_Type                 Petrol
# Seller_Type           Individual
# Transmission           Automatic
# Owner                          0
# Depreciation                0.03
# Name: 155, dtype: object

# %% [markdown]
# Most Depreciated Vehicle:land cruiser ,
# Least Depreciated Vehicle: Honda Activa 4G
#
# in this we added nuw coloum to the data set.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
#  9   Depreciation   301 non-null    float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 23.6+ KB

# %%
# 13 question
avg= df.groupby('Car_Name')['Depreciation'].mean()

# Find brands with lower average depreciation
less_affected = avg.sort_values()

print("Brands less affected by depreciation:")
print(less_affected)
# Out:
# Brands less affected by depreciation:
# Car_Name
# TVS Sport              0.040000
# Honda Activa 4G        0.045000
# Hero Passion X pro     0.050000
# Bajaj Avenger 150      0.050000
# Honda Dream Yuga       0.060000
#                         ...
# corolla altis         10.399375
# corolla               10.850000
# fortuner              12.047273
# camry                 21.230000
# land cruiser          57.600000
# Name: Depreciation, Length: 98, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#14 quetion
df['Vehicle_Age'] = 2024 - df['Year']
sns.scatterplot(x='Vehicle_Age', y='Selling_Price', data=df)
plt.title('Selling Price vs Year')
plt.xlabel('age')
plt.ylabel('Selling Price')
plt.show()

# %%
# 15 question
sns.scatterplot(x='Kms_Driven', y='Selling_Price', data=df)
plt.title('Selling Price vs Kms_Driven')
plt.ylabel('Selling Price')
plt.xlabel('Kms_Driven')
plt.show()

# %% [markdown]
#  YES is it observable from data that selling price is affected by age of vehicle and distance driven by vehicle.

# %%
# 16 question
newcars = df[df['Year'] > 2014]
newcars.head()
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
# 7        s cross  2015           6.50           8.61       33429    Diesel
# 8           ciaz  2016           8.75           8.89       20273    Diesel
#
#   Seller_Type Transmission  Owner  Depreciation  Vehicle_Age
# 2      Dealer       Manual      0          2.60            7
# 5      Dealer       Manual      0          0.58            6
# 6      Dealer       Manual      0          1.37            9
# 7      Dealer       Manual      0          2.11            9
# 8      Dealer       Manual      0          0.14            8

# %% [markdown]
# There are 147 vehicles in the dataset that were manufactured after 2014

# %%
# 17 question
two_wheelers = df[(df['Fuel_Type'] == 'Petrol') & (df['Present_Price'] < 3)]
two_wheelers = two_wheelers.loc[two_wheelers.Car_Name != "alto k10"]
two_wheelers = two_wheelers.loc[two_wheelers.Car_Name != "800"]
two_wheelers = two_wheelers.loc[two_wheelers.Car_Name != "omni"]
two_wheelers.head()
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  \
# 100  Royal Enfield Thunder 500  2016           1.75           1.90
# 101         UM Renegade Mojave  2017           1.70           1.82
# 102                  KTM RC200  2017           1.65           1.78
# 103          Bajaj Dominar 400  2017           1.45           1.60
# 104  Royal Enfield Classic 350  2017           1.35           1.47
#
#      Kms_Driven Fuel_Type Seller_Type Transmission  Owner  Depreciation  \
# 100        3000    Petrol  Individual       Manual      0          0.15
# 101        1400    Petrol  Individual       Manual      0          0.12
# 102        4000    Petrol  Individual       Manual      0          0.13
# 103        1200    Petrol  Individual       Manual      0          0.15
# 104        4100    Petrol  Individual       Manual      0          0.12
#
#      Vehicle_Age
# 100            8
# 101            7
# 102            7
# 103            7
# 104            7

# %% [markdown]
# to find the two wheeler we assume the price of bike less than 3 lakhs and fuel type is prtrol.

# %%
oldest = two_wheelers.loc[two_wheelers['Year'].idxmin()]
print(oldest)
# Out:
# Car_Name         Hero Super Splendor
# Year                            2005
# Selling_Price                    0.2
# Present_Price                   0.57
# Kms_Driven                     55000
# Fuel_Type                     Petrol
# Seller_Type               Individual
# Transmission                  Manual
# Owner                              0
# Depreciation                    0.37
# Vehicle_Age                       19
# Name: 189, dtype: object

# %% [markdown]
# the oldest bike is Hero Super Splendor form year 2005

# %%
# 18 question
newest = two_wheelers.loc[two_wheelers['Year'].idxmax()]
print(newest)
# Out:
# Car_Name         UM Renegade Mojave
# Year                           2017
# Selling_Price                   1.7
# Present_Price                  1.82
# Kms_Driven                     1400
# Fuel_Type                    Petrol
# Seller_Type              Individual
# Transmission                 Manual
# Owner                             0
# Depreciation                   0.12
# Vehicle_Age                       7
# Name: 101, dtype: object

# %% [markdown]
# the newest bike is UM Renegade Mojave form year 2017

# %%
# 19 question
most= two_wheelers['Car_Name'].value_counts()
most_two_wheeler = most.idxmax()
print(most_two_wheeler)
# Out:
# Royal Enfield Classic 350

# %% [markdown]
# most sold bike in the data is Royal Enfield Classic 350

# %%
#20 question
unexpected_deals = two_wheelers[two_wheelers['Selling_Price'] > two_wheelers['Selling_Price'].mean() + 2 * two_wheelers['Selling_Price'].std()]
print(unexpected_deals.head())
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  \
# 100  Royal Enfield Thunder 500  2016           1.75           1.90
# 101         UM Renegade Mojave  2017           1.70           1.82
# 102                  KTM RC200  2017           1.65           1.78
# 103          Bajaj Dominar 400  2017           1.45           1.60
#
#      Kms_Driven Fuel_Type Seller_Type Transmission  Owner  Depreciation  \
# 100        3000    Petrol  Individual       Manual      0          0.15
# 101        1400    Petrol  Individual       Manual      0          0.12
# 102        4000    Petrol  Individual       Manual      0          0.13
# 103        1200    Petrol  Individual       Manual      0          0.15
#
#      Vehicle_Age
# 100            8
# 101            7
# 102            7
# 103            7

# %% [markdown]
# unexpected_deals= current> MEAN + 2*S.D OF DATA.

# %%
#21 question
car = df[~df['Car_Name'].isin(two_wheelers['Car_Name'])]
print(car.head())
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Depreciation  Vehicle_Age
# 0      Dealer       Manual      0          2.24           10
# 1      Dealer       Manual      0          4.79           11
# 2      Dealer       Manual      0          2.60            7
# 3      Dealer       Manual      0          1.30           13
# 4      Dealer       Manual      0          2.27           10

# %% [markdown]
# here the data for cars is  data - two wheeler velhicls .

# %%
#22 question
oldest_car = car.loc[car['Year'].idxmin()]
print(oldest_car)
# Out:
# Car_Name                800
# Year                   2003
# Selling_Price          0.35
# Present_Price          2.28
# Kms_Driven           127000
# Fuel_Type            Petrol
# Seller_Type      Individual
# Transmission         Manual
# Owner                     0
# Depreciation           1.93
# Vehicle_Age              21
# Name: 37, dtype: object

# %% [markdown]
# the oldest car in the data is 800 which is from year 2003

# %%
#23 question
newest_car = car.loc[car['Year'].idxmax()]
print(newest_car)
# Out:
# Car_Name         vitara brezza
# Year                      2018
# Selling_Price             9.25
# Present_Price             9.83
# Kms_Driven                2071
# Fuel_Type               Diesel
# Seller_Type             Dealer
# Transmission            Manual
# Owner                        0
# Depreciation              0.58
# Vehicle_Age                  6
# Name: 5, dtype: object

# %% [markdown]
# the newest car in the data is vitara brezza which is from year 2018

# %%
# 24 question
unexpected_deals_car = car[car['Selling_Price'] > car['Selling_Price'].mean() + 2 * car['Selling_Price'].std()]
print(unexpected_deals_car.head())
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 51  fortuner  2015          23.00          30.61       40000    Diesel
# 52    innova  2017          18.00          19.77       15000    Diesel
# 59  fortuner  2014          19.99          35.96       41000    Diesel
# 62  fortuner  2014          18.75          35.96       78000    Diesel
# 63  fortuner  2015          23.50          35.96       47000    Diesel
#
#    Seller_Type Transmission  Owner  Depreciation  Vehicle_Age
# 51      Dealer    Automatic      0          7.61            9
# 52      Dealer    Automatic      0          1.77            7
# 59      Dealer    Automatic      0         15.97           10
# 62      Dealer    Automatic      0         17.21           10
# 63      Dealer    Automatic      0         12.46            9

# %% [markdown]
# unexpected_deals= current> MEAN + 2*S.D OF DATA
#
# or we can use graph to find the general expatataion

# %%
plt.boxplot(car.Selling_Price)
plt.show()

# %%
car[car.Selling_Price>14]
# Out:
#          Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 50       fortuner  2012          14.90          30.61      104707    Diesel
# 51       fortuner  2015          23.00          30.61       40000    Diesel
# 52         innova  2017          18.00          19.77       15000    Diesel
# 53       fortuner  2013          16.00          30.61      135000    Diesel
# 59       fortuner  2014          19.99          35.96       41000    Diesel
# 62       fortuner  2014          18.75          35.96       78000    Diesel
# 63       fortuner  2015          23.50          35.96       47000    Diesel
# 64       fortuner  2017          33.00          36.23        6000    Diesel
# 66         innova  2017          19.75          23.15       11000    Petrol
# 69  corolla altis  2016          14.25          20.91       12000    Petrol
# 79       fortuner  2012          14.50          30.61       89000    Diesel
# ...

# %%
fig_dims = (10,15)
fig ,ax = plt.subplots(figsize = fig_dims)
sns.countplot(y = car.Car_Name,ax = ax ,data = df)
# Out:
# <Axes: xlabel='count', ylabel='Car_Name'>

# %% [markdown]
# cars and their counts

# %%
fig_dims = (10,15)
fig ,ax = plt.subplots(figsize = fig_dims)
sns.countplot(y = two_wheelers.Car_Name,ax = ax ,data = df)
# Out:
# <Axes: xlabel='count', ylabel='Car_Name'>

# %% [markdown]
# bikes and their counts

# %%
# number of cars and bikes in different fuel type
df.Fuel_Type.value_counts().plot.bar()
plt.title('Fuel Type Distribution in cars')
plt.xlabel('Fuel Type')
plt.ylabel('Count')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.pie(car['Fuel_Type'].value_counts(), labels=["Petrol", "Diesel", "CNG"], autopct='%1.1f%%')
plt.title('Fuel Type Distribution in cars')
plt.show()

# %% [markdown]
# no of cars using different fuel type

# %%
#Fuel distubution in total data
plt.pie(df['Fuel_Type'].value_counts(), labels=["Petrol", "Diesel", "CNG"], autopct='%1.1f%%')
plt.title('Fuel Type Distribution')
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10, 4))
sns.countplot(x='Year',data=df)
plt.title('Cars per Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.boxplot(x='Fuel_Type', y='Selling_Price', data=df)
plt.title('Selling Price by Fuel Type')
plt.xlabel('Fuel Type')
plt.ylabel('Selling Price')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
